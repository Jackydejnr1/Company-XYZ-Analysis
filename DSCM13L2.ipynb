# %% [markdown]
# <a href="https://colab.research.google.com/github/Jackydejnr1/Company-XYZ-Analysis/blob/main/DSCM13L2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-83e6163b-921e-44f0-a89a-13d8d035615f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-83e6163b-921e-44f0-a89a-13d8d035615f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('gapminder(2007).csv')

# %%
data.head()
# Out:
#    Unnamed: 0      country  year  population continent  life_exp       gdp_cap
# 0          11  Afghanistan  2007    31889923      Asia    43.828    974.580338
# 1          23      Albania  2007     3600523    Europe    76.423   5937.029526
# 2          35      Algeria  2007    33333216    Africa    72.301   6223.367465
# 3          47       Angola  2007    12420476    Africa    42.731   4797.231267
# 4          59    Argentina  2007    40301927  Americas    75.320  12779.379640

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  142 non-null    int64
#  1   country     142 non-null    object
#  2   year        142 non-null    int64
#  3   population  142 non-null    int64
#  4   continent   142 non-null    object
#  5   life_exp    142 non-null    float64
#  6   gdp_cap     142 non-null    float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 7.9+ KB

# %%
data.isnull().any()
# Out:
# Unnamed: 0    False
# country       False
# year          False
# population    False
# continent     False
# life_exp      False
# gdp_cap       False
# dtype: bool

# %%
labels = ['population','life_exp','gdp_cap']

# %%
for l in labels:
  sns.boxplot(y=data[l], palette='winter')
  plt.show()
# Out:
# /tmp/ipython-input-1798378991.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=data[l], palette='winter')
# /tmp/ipython-input-1798378991.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=data[l], palette='winter')
# /tmp/ipython-input-1798378991.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=data[l], palette='winter')

# %%
sns.boxplot(y='gdp_cap', x='continent',data=data, palette='viridis')
# Out:
# /tmp/ipython-input-4203078982.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y='gdp_cap', x='continent',data=data, palette='viridis')
# <Axes: xlabel='continent', ylabel='gdp_cap'>

# %%
sns.boxplot(y='life_exp', x='continent',data=data, palette='viridis')
# Out:
# /tmp/ipython-input-3835745644.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y='life_exp', x='continent',data=data, palette='viridis')
# <Axes: xlabel='continent', ylabel='life_exp'>

# %%
sns.violinplot(y='gdp_cap', x='continent',data=data, palette='bright')
# Out:
# /tmp/ipython-input-1235747954.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y='gdp_cap', x='continent',data=data, palette='bright')
# <Axes: xlabel='continent', ylabel='gdp_cap'>

# %%
sns.violinplot(y='life_exp', x='continent',data=data, palette='bright')
# Out:
# /tmp/ipython-input-2631354234.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y='life_exp', x='continent',data=data, palette='bright')
# <Axes: xlabel='continent', ylabel='life_exp'>

# %%
for l in labels:
  sns.kdeplot(data[l])
  plt.show()

# %%
for l in labels:
  plt.hist(data[l])
  plt.xlabel(l)
  plt.show()

# %%
for l in labels:
  sns.distplot(data[l])
  plt.show()
  print("Skewness is :", data[l].skew())
# Out:
# /tmp/ipython-input-62549317.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[l])
# /tmp/ipython-input-62549317.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[l])
# Skewness is : 7.400873493029002
# Skewness is : -0.6887770648577504
# ...
